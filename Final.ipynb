# %% [markdown]
# # A PROGRAM FOR HACKATHON EVENT

# %%
import requests # to handle requests
import pandas as pd # for data analsysis
import numpy as np # to handle data in a vectorized manner

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
#tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.11.28         |           py36_0         149 KB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     openssl-1.1.1d             |       h516909a_0         2.1 MB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0         conda-forge
#     geopy:           1.20.0-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.11.27-0                  --> 2019.11.28-hecc5488_0 conda-forge
#     certifi:         2019.11.28-py36_0             --> 2019.11.28-py36_0     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1d-h7b6447c_3             --> 1.1.1d-h516909a_0     conda-forge
#
#
# Downloading and Extracting Packages
# certifi-2019.11.28   | 149 KB    | ##################################### | 100%
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# openssl-1.1.1d       | 2.1 MB    | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     altair-4.0.0               |             py_0         606 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         704 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  4.0.0-py_0 conda-forge
#     branca:  0.3.1-py_0 conda-forge
#     folium:  0.5.0-py_0 conda-forge
#     vincent: 0.4.4-py_1 conda-forge
#
#
# Downloading and Extracting Packages
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# altair-4.0.0         | 606 KB    | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# # FOUR SQUARE CREDENTIALS

# %%
ClIENT_ID = 'FN3SSHY5YSDJDHA5THZXW315E4ZJFDEO4IOTWFZZUSVKEWDZ' # your Foursquare ID
ClIENT_SECRET = 'VC1JLYNG2ZOZPN4E2JJ2WXD24EKJAA1VOTFYJGS3FJWKOANK' # your Foursquare Secret
VERSION = '20191218'
LIMIT =50
print('Your credentails:')
print('Foursquare_ID: ' + ClIENT_ID)
print('Foursquare_Secret:' + ClIENT_SECRET)
# Out:
# Your credentails:
# Foursquare_ID: FN3SSHY5YSDJDHA5THZXW315E4ZJFDEO4IOTWFZZUSVKEWDZ
# Foursquare_Secret:VC1JLYNG2ZOZPN4E2JJ2WXD24EKJAA1VOTFYJGS3FJWKOANK

# %% [markdown]
# # CITY AND LOCATION

# %%
# define the city and get its latitude & longitude 
city = 'Hyderabad'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 17.38878595 78.4610647345315

# %% [markdown]
# # HOTEL DATA

# %%
# search for hotels
search_query = 'Hotel'
radius = 3600

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=FN3SSHY5YSDJDHA5THZXW315E4ZJFDEO4IOTWFZZUSVKEWDZ&client_secret=VC1JLYNG2ZOZPN4E2JJ2WXD24EKJAA1VOTFYJGS3FJWKOANK&ll=17.38878595,78.4610647345315&v=20191218&query=Hotel&radius=3600&limit=50'

# %%
# Send the GET Request and examine the results
results = requests.get(url).json()
#results

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4d954b06a243a5684965b473', 'name': 'R...    False
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 3  [{'id': '4bf58dd8d48988d1d5941735', 'name': 'H...    False
# 4  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
#
#                          id                     location.address location.cc  \
# 0  520f63a311d26e0c0c70b21e                         Station road          IN
# 1  4bd77f3a304fce72baa333ab    11-4-649/C, AC Guards Lakdi-ka-Pu          IN
# 2  4be06fbf4c55b651426feab7  4-1-999, Abidi Road Chirag Ali Road          IN
# 3  4bd5c7299649ce7251a9511d                  10-1-124 Masab Tank          IN
# 4  4e162ff36284b506cfd78f49                           Chaderghat          IN
#
#   location.city location.country location.crossStreet  location.distance  \
# 0     Hyderābād            India                  NaN               1009
# 1     Hyderabad            India                  NaN               1574
# 2     Hyderabad            India                  NaN               1720
# 3     Hyderabad            India                  NaN               1901
# 4     Hyderabad            India                  NaN               3528
#
#                            location.formattedAddress  \
# 0        [Station road, Hyderābād, Telangana, India]
# 1  [11-4-649/C, AC Guards Lakdi-ka-Pu, Hyderabad,...
# 2  [4-1-999, Abidi Road Chirag Ali Road, Hyderaba...
# 3  [10-1-124 Masab Tank, Hyderabad 500028, Telang...
# 4   [Chaderghat, Hyderabad 500036, Telangana, India]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 17.39117831545719...     17.391178
# 1  [{'label': 'display', 'lat': 17.40291502609864...     17.402915
# 2  [{'label': 'display', 'lat': 17.39194189711636...     17.391942
# 3  [{'label': 'display', 'lat': 17.404457, 'lng':...     17.404457
# 4  [{'label': 'display', 'lat': 17.37710064393863...     17.377101
#
#    location.lng location.postalCode location.state                name  \
# 0     78.470230                 NaN      Telangana      Hotel Imperial
# 1     78.460450                 NaN      Telangana    Woodbridge Hotel
# 2     78.476915                 NaN      Telangana     Taj Mahal Hotel
# 3     78.453950              500028      Telangana  The Golkonda Hotel
# 4     78.491940              500036      Telangana        Hotel Savera
#
#      referralId
# 0  v-1576668747
# 1  v-1576668747
# 2  v-1576668747
# 3  v-1576668747
# 4  v-1576668747

# %% [markdown]
# # CLEAN HOTEL DATA

# %%
# keep only columns that include venue name, and anything that is associated with location
clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
clean_dataframe = dataframe.loc[:,clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
clean_dataframe['categories'] = clean_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_dataframe.columns = [column.split('.')[-1] for column in clean_dataframe.columns]

clean_dataframe.head()
# Out:
#                  name                                categories  \
# 0      Hotel Imperial  Residential Building (Apartment / Condo)
# 1    Woodbridge Hotel                                     Hotel
# 2     Taj Mahal Hotel                                     Hotel
# 3  The Golkonda Hotel                                 Hotel Bar
# 4        Hotel Savera                                     Hotel
#
#                                address  cc       city country crossStreet  \
# 0                         Station road  IN  Hyderābād   India         NaN
# 1    11-4-649/C, AC Guards Lakdi-ka-Pu  IN  Hyderabad   India         NaN
# 2  4-1-999, Abidi Road Chirag Ali Road  IN  Hyderabad   India         NaN
# 3                  10-1-124 Masab Tank  IN  Hyderabad   India         NaN
# 4                           Chaderghat  IN  Hyderabad   India         NaN
#
#    distance                                   formattedAddress  \
# 0      1009        [Station road, Hyderābād, Telangana, India]
# 1      1574  [11-4-649/C, AC Guards Lakdi-ka-Pu, Hyderabad,...
# 2      1720  [4-1-999, Abidi Road Chirag Ali Road, Hyderaba...
# 3      1901  [10-1-124 Masab Tank, Hyderabad 500028, Telang...
# 4      3528   [Chaderghat, Hyderabad 500036, Telangana, India]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 17.39117831545719...  17.391178  78.470230
# 1  [{'label': 'display', 'lat': 17.40291502609864...  17.402915  78.460450
# 2  [{'label': 'display', 'lat': 17.39194189711636...  17.391942  78.476915
# 3  [{'label': 'display', 'lat': 17.404457, 'lng':...  17.404457  78.453950
# 4  [{'label': 'display', 'lat': 17.37710064393863...  17.377101  78.491940
#
#   postalCode      state                        id
# 0        NaN  Telangana  520f63a311d26e0c0c70b21e
# 1        NaN  Telangana  4bd77f3a304fce72baa333ab
# 2        NaN  Telangana  4be06fbf4c55b651426feab7
# 3     500028  Telangana  4bd5c7299649ce7251a9511d
# 4     500036  Telangana  4e162ff36284b506cfd78f49

# %%
# delete unnecessary columns
clean_dataframe2= clean_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress', 'labeledLatLngs','id'],axis=1)
clean_dataframe2
# Out:
#                                   name  \
# 0                       Hotel Imperial
# 1                     Woodbridge Hotel
# 2                      Taj Mahal Hotel
# 3                   The Golkonda Hotel
# 4                         Hotel Savera
# 5                Hampshire Plaza Hotel
# 6   Hotel Mandakini Jaya International
# 7                         Hotel Nayaab
# 8                       Hotel Rajdhani
# 9            Alliance Woodbridge Hotel
# 10                      Hotel Mansingh
# 11                       Hotel Marjaan
# 12                Al-humdulillah Hotel
# 13           Cassia - Hotel Hamphshire
# 14                 Hotel Swagath Grand
# 15             The Central Court Hotel
# 16                        Hotel Kamath
# 17             Hotel raj international
# 18                        Hotel Arastu
# 19                Hotel Celestee Grand
# 20                      Hotel Royalton
# 21                      Hotel imperiar
# 22                        Hotel Famous
# 23                      The Park Hotel
# 24                       Hotel Firdous
# 25                       Hotel Gateway
# 26              Katriya Hotel & Towers
# 27                        Hotel Harsha
# 28                       Hotel Rajmata
# 29                  Hotel Silver Point
# 30                   Hotel Kanha Grand
# 31                        Hotel Marjan
# 32          New Gulzar Yousufain Hotel
# 33              Hotel Saptagiri Deluxe
# 34                  City Diamond Hotel
# 35             Hotel Sri Supraja Pride
# 36                     Hotel Royal Sea
# 37               Hotel Royal Residency
# 38                 Hotel Pearl Regency
# 39                    Hotel Riya Grand
# 40                   Hotel Grand plaza
# 41                       Hotel Mercure
# 42                        Nimrah Hotel
# 43                        Hotel Asiana
# 44                      Hotel Fishland
# 45                        hotel suhail
# 46                          Hotel Indu
# 47            Hotel R -Inn Continental
# 48                        Voulga Hotel
# 49                     Hotel Mandakini
#
#                                   categories  \
# 0   Residential Building (Apartment / Condo)
# 1                                      Hotel
# 2                                      Hotel
# 3                                  Hotel Bar
# 4                                      Hotel
# 5                                      Hotel
# 6                                      Hotel
# 7                                 Food Court
# 8                                      Hotel
# 9                                      Hotel
# 10                         Indian Restaurant
# 11                                      Café
# 12                         Indian Restaurant
# 13                         Indian Restaurant
# 14                      Fast Food Restaurant
# 15                                     Hotel
# 16                                      Café
# 17                                Hotel Pool
# 18                           Bed & Breakfast
# 19                                     Hotel
# 20                                     Hotel
# 21  Residential Building (Apartment / Condo)
# 22                            Boarding House
# 23                                     Hotel
# 24                         Indian Restaurant
# 25                             Travel Lounge
# 26                                     Hotel
# 27                                     Hotel
# 28                                    Hostel
# 29                                      None
# 30                           Bed & Breakfast
# 31                                     Hotel
# 32                                      None
# 33                           Bed & Breakfast
# 34                                Restaurant
# 35                                     Hotel
# 36                                      Café
# 37                           Bed & Breakfast
# 38                                     Hotel
# 39                           Bed & Breakfast
# 40                                     Hotel
# 41                                     Hotel
# 42                                      Café
# 43                          Asian Restaurant
# 44                         Indian Restaurant
# 45                                     Hotel
# 46                                      None
# 47                           Bed & Breakfast
# 48                                      Café
# 49                                     Hotel
#
#                                         address        lat        lng  \
# 0                                  Station road  17.391178  78.470230
# 1             11-4-649/C, AC Guards Lakdi-ka-Pu  17.402915  78.460450
# 2           4-1-999, Abidi Road Chirag Ali Road  17.391942  78.476915
# 3                           10-1-124 Masab Tank  17.404457  78.453950
# 4                                    Chaderghat  17.377101  78.491940
# 5                       6-1-79 & 80, Lakdikapul  17.405397  78.464407
# 6                            Hanuman tekdi road  17.385698  78.476934
# 7                                     Charminar  17.368504  78.477480
# 8                             Siddiamber Bazaar  17.378295  78.474986
# 9            11-4-649/C AC GUARDS LAKDI KA POOL  17.402977  78.459991
# 10                                 Begum Bazaar  17.376543  78.475747
# 11                                          NaN  17.395373  78.455115
# 12                                          NaN  17.390728  78.462992
# 13                                   Lakdikapul  17.404809  78.461033
# 14                                      Attapur  17.380493  78.429133
# 15                         6-1-71, Lakdi ka Pul  17.404201  78.464950
# 16                                          NaN  17.390799  78.471006
# 17                                Nampally road  17.392892  78.463919
# 18                                          NaN  17.391482  78.465582
# 19  H.no - 11-6-460-465, Dargah Road, Nampally,  17.392014  78.465233
# 20                                          NaN  17.393211  78.473504
# 21                                     Nampally  17.388606  78.468337
# 22                                          NaN  17.390976  78.468021
# 23                             22 Raj Bhavan Rd  17.423605  78.462401
# 24                                          NaN  17.378550  78.493727
# 25                                          NaN  17.392333  78.469353
# 26                 8 Rajbhavan Road, Somajiguda  17.424833  78.459583
# 27                        39 public garden road  17.392818  78.470785
# 28                                          NaN  17.392639  78.471001
# 29                      Near By MedWin Hospital  17.394849  78.470074
# 30                                   11-5-341/2  17.399285  78.462768
# 31                                          NaN  17.394911  78.470747
# 32                                  Lingamurthy  17.393492  78.465685
# 33                                          NaN  17.388108  78.473271
# 34                                          NaN  17.389250  78.453568
# 35                                          NaN  17.388592  78.474945
# 36                                          NaN  17.401358  78.457208
# 37                                          NaN  17.402789  78.463153
# 38                                          NaN  17.401616  78.463678
# 39                                #11-6-872/A/B  17.402283  78.466706
# 40                                          NaN  17.397877  78.470802
# 41                       Near Fateh Sultan Road  17.393191  78.473576
# 42                                          NaN  17.361136  78.474373
# 43                                          NaN  17.398127  78.449486
# 44                       Opposite Dwaraka Hotel  17.405732  78.462559
# 45                                          NaN  17.395960  78.475128
# 46                                Near Assembly  17.403599  78.467699
# 47         11-6-872/1/A, Redhills, Lakdi-ka-pul  17.403793  78.464779
# 48                                Khilwath Road  17.355043  78.468970
# 49                                          NaN  17.388250  78.477715
#
#    postalCode           state
# 0         NaN       Telangana
# 1         NaN       Telangana
# 2         NaN       Telangana
# 3      500028       Telangana
# 4      500036       Telangana
# 5         NaN       Telangana
# 6         NaN  Andhra Pradesh
# 7         NaN             NaN
# 8         NaN       Telangana
# 9         NaN       Telangana
# 10        NaN       Telangana
# 11        NaN             NaN
# 12        NaN             NaN
# 13        NaN       Telangana
# 14     500008       Telangana
# 15        NaN       Telangana
# 16        NaN             NaN
# 17        NaN  Andhra pradesg
# 18        NaN             NaN
# 19     500001       Telangana
# 20        NaN       Telangana
# 21        NaN       Telangana
# 22        NaN             NaN
# 23     500082       Telangana
# 24        NaN             NaN
# 25        NaN             NaN
# 26        NaN       Telangana
# 27     500001       Telangana
# 28        NaN             NaN
# 29        NaN  Andhra Pradesh
# 30     500004       Telangana
# 31        NaN             NaN
# 32        NaN  Andhra Pradesh
# 33        NaN             NaN
# 34        NaN             NaN
# 35        NaN             NaN
# 36        NaN             NaN
# 37        NaN       Telangana
# 38        NaN  Andhra Pradesh
# 39     500004       Telangana
# 40        NaN       Telangana
# 41        NaN       Telangana
# 42     500002       Telangana
# 43        NaN             NaN
# 44     500004       Telangana
# 45        NaN             NaN
# 46        NaN       Telangana
# 47     500004       Telangana
# 48        NaN       Telangana
# 49        NaN             NaN

# %%
# delete rows with none values
clean_dataframe3 = clean_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_dataframe3
# Out:
#                         name            categories  \
# 3         The Golkonda Hotel             Hotel Bar
# 4               Hotel Savera                 Hotel
# 14       Hotel Swagath Grand  Fast Food Restaurant
# 19      Hotel Celestee Grand                 Hotel
# 23            The Park Hotel                 Hotel
# 27              Hotel Harsha                 Hotel
# 30         Hotel Kanha Grand       Bed & Breakfast
# 39          Hotel Riya Grand       Bed & Breakfast
# 44            Hotel Fishland     Indian Restaurant
# 47  Hotel R -Inn Continental       Bed & Breakfast
#
#                                         address        lat        lng  \
# 3                           10-1-124 Masab Tank  17.404457  78.453950
# 4                                    Chaderghat  17.377101  78.491940
# 14                                      Attapur  17.380493  78.429133
# 19  H.no - 11-6-460-465, Dargah Road, Nampally,  17.392014  78.465233
# 23                             22 Raj Bhavan Rd  17.423605  78.462401
# 27                        39 public garden road  17.392818  78.470785
# 30                                   11-5-341/2  17.399285  78.462768
# 39                                #11-6-872/A/B  17.402283  78.466706
# 44                       Opposite Dwaraka Hotel  17.405732  78.462559
# 47         11-6-872/1/A, Redhills, Lakdi-ka-pul  17.403793  78.464779
#
#    postalCode      state
# 3      500028  Telangana
# 4      500036  Telangana
# 14     500008  Telangana
# 19     500001  Telangana
# 23     500082  Telangana
# 27     500001  Telangana
# 30     500004  Telangana
# 39     500004  Telangana
# 44     500004  Telangana
# 47     500004  Telangana

# %%
# choose the hotel which has the same postalCode with the event space
df_hotel = df_hotels[df_hotels.postalCode == '500001']
df_hotel
# Out:
#                     name categories  \
# 19  Hotel Celestee Grand      Hotel
# 27          Hotel Harsha      Hotel
#
#                                         address        lat        lng  \
# 19  H.no - 11-6-460-465, Dargah Road, Nampally,  17.392014  78.465233
# 27                        39 public garden road  17.392818  78.470785
#
#    postalCode      state
# 19     500001  Telangana
# 27     500001  Telangana

# %% [markdown]
# # PARKS IN AREA

# %%
# search for Parks
search_query = 'Park'
radius = 45000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=FN3SSHY5YSDJDHA5THZXW315E4ZJFDEO4IOTWFZZUSVKEWDZ&client_secret=VC1JLYNG2ZOZPN4E2JJ2WXD24EKJAA1VOTFYJGS3FJWKOANK&ll=17.38878595,78.4610647345315&v=20191218&query=Park&radius=45000&limit=50'

# %%
# Send the GET Request and examine the results
presults = requests.get(url).json()
#presults

# %%
# assign relevant part of JSON to venues
venues = presults['response']['venues']

# tranform venues into a dataframe
park_dataframe = json_normalize(venues)
park_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...    False
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 4  [{'id': '4bf58dd8d48988d1f8941735', 'name': 'F...    False
#
#                          id          location.address location.cc  \
# 0  4ce914cbf3bda14382d2bde4         KBR National Park          IN
# 1  4f93cb30e4b03828fe09326a  Road No. 2 Banjara Hills          IN
# 2  4be1701a8dd062b583483e3c          22 Raj Bhavan Rd          IN
# 3  595cd1892bf9a971a2b91b3e               Mehdipatnam          IN
# 4  501ea97ae4b0d43ab64431e3                       NaN          IN
#
#   location.city location.country location.crossStreet  location.distance  \
# 0     Hyderabad            India       LV Prasad Marg               5586
# 1     Hyderabad            India                  NaN               5216
# 2     Hyderabad            India           Somajiguda               3878
# 3     Hyderabad            India                  NaN               1787
# 4           NaN            India                  NaN                978
#
#                            location.formattedAddress  \
# 0  [KBR National Park (LV Prasad Marg), Hyderabad...
# 1  [Road No. 2 Banjara Hills, Hyderabad 500034, T...
# 2  [22 Raj Bhavan Rd (Somajiguda), Hyderabad 5000...
# 3         [Mehdipatnam, Hyderabad 500057, TG, India]
# 4                                            [India]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 17.42536930610665...     17.425369
# 1  [{'label': 'display', 'lat': 17.42476445227363...     17.424764
# 2  [{'label': 'display', 'lat': 17.42360500386294...     17.423605
# 3  [{'label': 'display', 'lat': 17.399034, 'lng':...     17.399034
# 4  [{'label': 'display', 'lat': 17.38992994637108...     17.389930
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0     78.425063         Jubilee Hills                 NaN      Telangana
# 1     78.429600                   NaN              500034             TG
# 2     78.462401                   NaN              500082      Telangana
# 3     78.448108                   NaN              500057             TG
# 4     78.470202                   NaN                 NaN            NaN
#
#                      name    referralId
# 0                KBR Park  v-1576669802
# 1    Park Hyatt Hyderabad  v-1576669802
# 2          The Park Hotel  v-1576669802
# 3  Park Continental Hotel  v-1576669802
# 4       The interior park  v-1576669802

# %% [markdown]
# # CLEANING PARK DATA

# %%
# keep only columns that include venue name, and anything that is associated with location
park_clean_columns = ['name', 'categories'] + [col for col in park_dataframe.columns if col.startswith('location.')]+ ['id']
clean_park_dataframe = park_dataframe.loc[:,park_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

# filter the category for each row
clean_park_dataframe['categories'] = clean_park_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_park_dataframe.columns = [column.split('.')[-1] for column in clean_park_dataframe.columns]

clean_park_dataframe.head()
# Out:
#                      name              categories                   address  \
# 0                KBR Park                    Park         KBR National Park
# 1    Park Hyatt Hyderabad                   Hotel  Road No. 2 Banjara Hills
# 2          The Park Hotel                   Hotel          22 Raj Bhavan Rd
# 3  Park Continental Hotel                   Hotel               Mehdipatnam
# 4       The interior park  Furniture / Home Store                       NaN
#
#    cc       city country     crossStreet  distance  \
# 0  IN  Hyderabad   India  LV Prasad Marg      5586
# 1  IN  Hyderabad   India             NaN      5216
# 2  IN  Hyderabad   India      Somajiguda      3878
# 3  IN  Hyderabad   India             NaN      1787
# 4  IN        NaN   India             NaN       978
#
#                                     formattedAddress  \
# 0  [KBR National Park (LV Prasad Marg), Hyderabad...
# 1  [Road No. 2 Banjara Hills, Hyderabad 500034, T...
# 2  [22 Raj Bhavan Rd (Somajiguda), Hyderabad 5000...
# 3         [Mehdipatnam, Hyderabad 500057, TG, India]
# 4                                            [India]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 17.42536930610665...  17.425369  78.425063
# 1  [{'label': 'display', 'lat': 17.42476445227363...  17.424764  78.429600
# 2  [{'label': 'display', 'lat': 17.42360500386294...  17.423605  78.462401
# 3  [{'label': 'display', 'lat': 17.399034, 'lng':...  17.399034  78.448108
# 4  [{'label': 'display', 'lat': 17.38992994637108...  17.389930  78.470202
#
#     neighborhood postalCode      state                        id
# 0  Jubilee Hills        NaN  Telangana  4ce914cbf3bda14382d2bde4
# 1            NaN     500034         TG  4f93cb30e4b03828fe09326a
# 2            NaN     500082  Telangana  4be1701a8dd062b583483e3c
# 3            NaN     500057         TG  595cd1892bf9a971a2b91b3e
# 4            NaN        NaN        NaN  501ea97ae4b0d43ab64431e3

# %%
# delete unnecessary columns
clean_park_dataframe2= clean_park_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'neighborhood','formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_park_dataframe2
# Out:
#                                             name  \
# 0                                       KBR Park
# 1                           Park Hyatt Hyderabad
# 2                                 The Park Hotel
# 3                         Park Continental Hotel
# 4                              The interior park
# 5                                      Park view
# 6                                  The Park View
# 7                         Jalagam Vengalrao Park
# 8           Raheja Mindspace IT Park, Building 9
# 9                               Hotel Green Park
# 10                             Chacha Nehru Park
# 11                                 oxy rich park
# 12                             OYO The City Park
# 13                   Sanjivaiah park rly station
# 14                          srinagar colony park
# 15                                  Lumbini Park
# 16                             Aditya Park Hotel
# 17                                   Indira Park
# 18                   Ashok Nagar Children's Park
# 19                                      THE PARK
# 20               Comfort Inn City Park Hyderabad
# 21                                  The Veg Park
# 22                               Sundarayya park
# 23                      Giridhari Executive Park
# 24                            Hotel Central Park
# 25                       Priyadarshini HMDA Park
# 26                                       Parking
# 27                         Nehru Zoological Park
# 28                        Boating @ Lumbini Park
# 29                     Park Hyatt Fitness Center
# 30                         Bunjee @ Lumbini Park
# 31  Deccan Park (Tata Consultancy Services Ltd.)
# 32                   Nostradamus At Fortune Park
# 33                          Park View Apartments
# 34                                 Lakeview Park
# 35                                Lake View Park
# 36                                   park avenue
# 37                                     Park Lane
# 38                     Venkataramana Colony Park
# 39                            Domalguda Park(DP)
# 40                                       PP Park
# 41                                 People's Park
# 42                                  Melkote park
# 43              Aditiya Park Inn Hotel Hyderabad
# 44                          Park Hyatt Hyderabad
# 45                              Narayanguda Park
# 46                     The Orchid - Fortune Park
# 47              Fortune  park vallabha Hyderabad
# 48                                      NTR Park
# 49                     7004 Room, The Park Hotel
#
#                                   categories  \
# 0                                       Park
# 1                                      Hotel
# 2                                      Hotel
# 3                                      Hotel
# 4                     Furniture / Home Store
# 5   Residential Building (Apartment / Condo)
# 6                                 Smoke Shop
# 7                                       Park
# 8                                     Office
# 9                                      Hotel
# 10                                      Park
# 11                                      Park
# 12                                     Hotel
# 13                        Light Rail Station
# 14                                      Park
# 15                                      Park
# 16                                     Hotel
# 17                                      Park
# 18                                      Park
# 19                                      Park
# 20                           Bed & Breakfast
# 21                   North Indian Restaurant
# 22                                      Park
# 23  Residential Building (Apartment / Condo)
# 24                                 Rest Area
# 25                            Scenic Lookout
# 26                                   Parking
# 27                                       Zoo
# 28                             Boat or Ferry
# 29                      Gym / Fitness Center
# 30                                      Park
# 31                                    Office
# 32                                    Lounge
# 33  Residential Building (Apartment / Condo)
# 34                                      Park
# 35                                      Park
# 36                            Clothing Store
# 37                                    Arcade
# 38                                      Park
# 39                                      Park
# 40                                      Park
# 41                                      Park
# 42                                      Park
# 43                           Bed & Breakfast
# 44                                Hotel Pool
# 45                                      Park
# 46                                     Diner
# 47                                Hotel Pool
# 48                                Playground
# 49                           Other Nightlife
#
#                                               address        lat        lng  \
# 0                                   KBR National Park  17.425369  78.425063
# 1                            Road No. 2 Banjara Hills  17.424764  78.429600
# 2                                    22 Raj Bhavan Rd  17.423605  78.462401
# 3                                         Mehdipatnam  17.399034  78.448108
# 4                                                 NaN  17.389930  78.470202
# 5                                                 NaN  17.466397  78.485148
# 6                                                 NaN  17.424646  78.423025
# 7                                           Road No 1  17.422526  78.448826
# 8                                                 NaN  17.394800  78.470600
# 9                   Ameerpet Rd, Greenlands, Begumpet  17.436276  78.453892
# 10                                         Masab Tank  17.401969  78.449486
# 11                                                NaN  17.400322  78.454988
# 12  The city park, 5-8-457-489, Chirag AlicLane, A...  17.391635  78.474416
# 13                                                NaN  17.435000  78.476302
# 14                                                NaN  17.429563  78.439682
# 15                                Opp. AP Secretariat  17.409307  78.472439
# 16                      Aditya Trade Centre, Ameerpet  17.436140  78.446450
# 17                                                NaN  17.412103  78.481430
# 18                              Ashok Nagar Main Road  17.405775  78.489748
# 19                                      chintal basti  17.413519  78.453289
# 20                   5-8-457 to 489 Chirag Ali, Abids  17.386835  78.479931
# 21                                                NaN  17.403050  78.476509
# 22                                     Baglingampally  17.397676  78.503842
# 23                                       Shivrampally  17.398230  78.481968
# 24                                                NaN  17.399091  78.480830
# 25                                        Saroornagar  17.351851  78.535375
# 26                              Nehru Zoological Park  17.350932  78.452373
# 27                        Zoo Park Main Rd, Charminar  17.350778  78.451396
# 28                                       Lumbini Park  17.412100  78.465484
# 29                           Road No. 2 Banjara Hills  17.424935  78.429493
# 30                                                NaN  17.411069  78.474903
# 31                   Plot No.1, Software Units Layout  17.444592  78.378424
# 32                                                NaN  17.411499  78.435386
# 33                               SBI Officer's Colony  17.400952  78.505043
# 34                                   Opp Prasadz IMAX  17.415017  78.463858
# 35                                                NaN  17.412341  78.448204
# 36                                         Road no. 2  17.424115  78.430682
# 37                                          Park Lane  17.439547  78.489633
# 38                                                NaN  17.416313  78.452473
# 39                                                NaN  17.405974  78.485953
# 40                                                NaN  17.417693  78.441174
# 41                                                NaN  17.405159  78.493531
# 42                                       Vitthal vadi  17.398335  78.489027
# 43                            Aditya Enclave Hyderbad  17.405507  78.489112
# 44                          Road No. 2, Banjara Hills  17.446375  78.392241
# 45                                                NaN  17.396579  78.494587
# 46               Fortune Park Vallabha, Banjara Hills  17.411403  78.435634
# 47                                                NaN  17.411264  78.435419
# 48                                                NaN  17.411302  78.486302
# 49                                                NaN  17.422775  78.461960
#
#    postalCode           state
# 0         NaN       Telangana
# 1      500034              TG
# 2      500082       Telangana
# 3      500057              TG
# 4         NaN             NaN
# 5         NaN             NaN
# 6         NaN             NaN
# 7         NaN       Telangana
# 8         NaN             NaN
# 9      560016       Telangana
# 10     500028       Telangana
# 11        NaN             NaN
# 12     500001              TG
# 13        NaN             NaN
# 14        NaN             NaN
# 15        NaN       Telangana
# 16        NaN       Telangana
# 17        NaN       Telangana
# 18     500020       Telangana
# 19        NaN       Telangana
# 20        NaN       Telangana
# 21        NaN             NaN
# 22        NaN             NaN
# 23        NaN       Telangana
# 24        NaN             NaN
# 25        NaN             NaN
# 26        NaN       Telangana
# 27        NaN       Telangana
# 28        NaN       Telangana
# 29        NaN             NaN
# 30        NaN             NaN
# 31     500081       Telangana
# 32        NaN       Telangana
# 33     500013       Telangana
# 34        NaN       Telangana
# 35        NaN             NaN
# 36        NaN             NaN
# 37        NaN       Telangana
# 38        NaN             NaN
# 39        NaN             NaN
# 40        NaN             NaN
# 41        NaN             NaN
# 42        NaN       Telangana
# 43        NaN       Telangana
# 44     500034       Telangana
# 45        NaN             NaN
# 46     500034       Telangana
# 47        NaN             NaN
# 48        NaN  Andhra Pradesh
# 49        NaN             NaN

# %%
# delete rows with none values
clean_park_dataframe3 = clean_park_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_park_dataframe3
# Out:
#                                             name  \
# 1                           Park Hyatt Hyderabad
# 2                                 The Park Hotel
# 3                         Park Continental Hotel
# 9                               Hotel Green Park
# 10                             Chacha Nehru Park
# 12                             OYO The City Park
# 18                   Ashok Nagar Children's Park
# 31  Deccan Park (Tata Consultancy Services Ltd.)
# 33                          Park View Apartments
# 44                          Park Hyatt Hyderabad
# 46                     The Orchid - Fortune Park
#
#                                   categories  \
# 1                                      Hotel
# 2                                      Hotel
# 3                                      Hotel
# 9                                      Hotel
# 10                                      Park
# 12                                     Hotel
# 18                                      Park
# 31                                    Office
# 33  Residential Building (Apartment / Condo)
# 44                                Hotel Pool
# 46                                     Diner
#
#                                               address        lat        lng  \
# 1                            Road No. 2 Banjara Hills  17.424764  78.429600
# 2                                    22 Raj Bhavan Rd  17.423605  78.462401
# 3                                         Mehdipatnam  17.399034  78.448108
# 9                   Ameerpet Rd, Greenlands, Begumpet  17.436276  78.453892
# 10                                         Masab Tank  17.401969  78.449486
# 12  The city park, 5-8-457-489, Chirag AlicLane, A...  17.391635  78.474416
# 18                              Ashok Nagar Main Road  17.405775  78.489748
# 31                   Plot No.1, Software Units Layout  17.444592  78.378424
# 33                               SBI Officer's Colony  17.400952  78.505043
# 44                          Road No. 2, Banjara Hills  17.446375  78.392241
# 46               Fortune Park Vallabha, Banjara Hills  17.411403  78.435634
#
#    postalCode      state
# 1      500034         TG
# 2      500082  Telangana
# 3      500057         TG
# 9      560016  Telangana
# 10     500028  Telangana
# 12     500001         TG
# 18     500020  Telangana
# 31     500081  Telangana
# 33     500013  Telangana
# 44     500034  Telangana
# 46     500034  Telangana

# %%
# delete rows which its category is not Park
df_park = clean_park_dataframe3[clean_park_dataframe3.categories == 'Park']
df_park
# Out:
#                            name categories                address        lat  \
# 10            Chacha Nehru Park       Park             Masab Tank  17.401969
# 18  Ashok Nagar Children's Park       Park  Ashok Nagar Main Road  17.405775
#
#           lng postalCode      state
# 10  78.449486     500028  Telangana
# 18  78.489748     500020  Telangana

# %% [markdown]
# # SEARCHING RESTAURANTS

# %%
# search for Restaurants
search_query = 'Restaurant'
radius = 36000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=FN3SSHY5YSDJDHA5THZXW315E4ZJFDEO4IOTWFZZUSVKEWDZ&client_secret=VC1JLYNG2ZOZPN4E2JJ2WXD24EKJAA1VOTFYJGS3FJWKOANK&ll=17.38878595,78.4610647345315&v=20191218&query=Restaurant&radius=36000&limit=50'

# %%
# Send the GET Request and examine the results
Rresults = requests.get(url).json()
#Rresults

# %%
# assign relevant part of JSON to venues
venues = Rresults['response']['venues']

# tranform venues into a dataframe
Restaurant_dataframe = json_normalize(venues)
Restaurant_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d115941735', 'name': 'M...    False
# 1  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
# 2  [{'id': '54135bf5e4b08f3d2429dfe6', 'name': 'H...    False
# 3  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
# 4  [{'id': '503287a291d4c4b30a586d65', 'name': 'F...    False
#
#                          id   location.address location.cc location.city  \
# 0  517bee0be4b055745975c517                NaN          IN           NaN
# 1  4f9433d3e4b0949d21694780  Adj. Prince Hotel          IN     Hyderabad
# 2  4bcee9d1cc8cd13a5efdc4cf    Paradise Circle          IN  Secunderabad
# 3  4c81163ad92ea093375a3d72        Toli Chowli          IN     Hyderabad
# 4  5823557cda82023188157a2f                NaN          IN     Hyderabad
#
#   location.country location.crossStreet  location.distance  \
# 0            India                  NaN               3109
# 1            India          Meraj Hotel               2076
# 2            India                  NaN               6533
# 3            India                    M               3911
# 4            India                  NaN                541
#
#                            location.formattedAddress  \
# 0                                            [India]
# 1  [Adj. Prince Hotel (Meraj Hotel), Hyderabad 50...
# 2  [Paradise Circle, Secunderabad 500003, Telanga...
# 3  [Toli Chowli (M), Hyderabad 500058, Telangana,...
# 4                      [Hyderabad, Telangana, India]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 17.39536160730009...     17.395362
# 1  [{'label': 'display', 'lat': 17.39448615049604...     17.394486
# 2  [{'label': 'display', 'lat': 17.44184420016073...     17.441844
# 3  [{'label': 'display', 'lat': 17.3962770409263,...     17.396277
# 4  [{'label': 'display', 'lat': 17.38612646647625...     17.386126
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0     78.432614                   NaN                 NaN            NaN
# 1     78.442452                   NaN              500028      Telangana
# 2     78.487354                   NaN              500003      Telangana
# 3     78.425094                   NaN              500058      Telangana
# 4     78.456796                   NaN                 NaN      Telangana
#
#                               name    referralId
# 0     Al Rabea Al Arabi Restaurant  v-1576669916
# 1       Akbar Fast Food Restaurant  v-1576669916
# 2              Paradise Restaurant  v-1576669916
# 3  Shah Ghouse Cafe and Restaurant  v-1576669916
# 4                Grills restaurant  v-1576669916

# %% [markdown]
# # CLEAN RESTAURANT DATAFRAME

# %%
# keep only columns that include venue name, and anything that is associated with location
Restaurant_clean_columns = ['name', 'categories'] + [col for col in Restaurant_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Restaurant_dataframe = Restaurant_dataframe.loc[:,Restaurant_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list3 = row['categories']
    except:
        categories_list3 = row['venue.categories']
        
    if len(categories_list3) == 0:
        return None
    else:
        return categories_list3[0]['name']

# filter the category for each row
clean_Restaurant_dataframe['categories'] = clean_Restaurant_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Restaurant_dataframe.columns = [column.split('.')[-1] for column in clean_Restaurant_dataframe.columns]

clean_Restaurant_dataframe.head()
# Out:
#                               name                  categories  \
# 0     Al Rabea Al Arabi Restaurant   Middle Eastern Restaurant
# 1       Akbar Fast Food Restaurant           Indian Restaurant
# 2              Paradise Restaurant       Hyderabadi Restaurant
# 3  Shah Ghouse Cafe and Restaurant           Indian Restaurant
# 4                Grills restaurant  Financial or Legal Service
#
#              address  cc          city country  crossStreet  distance  \
# 0                NaN  IN           NaN   India          NaN      3109
# 1  Adj. Prince Hotel  IN     Hyderabad   India  Meraj Hotel      2076
# 2    Paradise Circle  IN  Secunderabad   India          NaN      6533
# 3        Toli Chowli  IN     Hyderabad   India            M      3911
# 4                NaN  IN     Hyderabad   India          NaN       541
#
#                                     formattedAddress  \
# 0                                            [India]
# 1  [Adj. Prince Hotel (Meraj Hotel), Hyderabad 50...
# 2  [Paradise Circle, Secunderabad 500003, Telanga...
# 3  [Toli Chowli (M), Hyderabad 500058, Telangana,...
# 4                      [Hyderabad, Telangana, India]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 17.39536160730009...  17.395362  78.432614
# 1  [{'label': 'display', 'lat': 17.39448615049604...  17.394486  78.442452
# 2  [{'label': 'display', 'lat': 17.44184420016073...  17.441844  78.487354
# 3  [{'label': 'display', 'lat': 17.3962770409263,...  17.396277  78.425094
# 4  [{'label': 'display', 'lat': 17.38612646647625...  17.386126  78.456796
#
#   neighborhood postalCode      state                        id
# 0          NaN        NaN        NaN  517bee0be4b055745975c517
# 1          NaN     500028  Telangana  4f9433d3e4b0949d21694780
# 2          NaN     500003  Telangana  4bcee9d1cc8cd13a5efdc4cf
# 3          NaN     500058  Telangana  4c81163ad92ea093375a3d72
# 4          NaN        NaN  Telangana  5823557cda82023188157a2f

# %%
# delete unnecessary columns
clean_Restaurant_dataframe2= clean_Restaurant_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Restaurant_dataframe2
# Out:
#                                          name                      categories  \
# 0                Al Rabea Al Arabi Restaurant       Middle Eastern Restaurant
# 1                  Akbar Fast Food Restaurant               Indian Restaurant
# 2                         Paradise Restaurant           Hyderabadi Restaurant
# 3             Shah Ghouse Cafe and Restaurant               Indian Restaurant
# 4                           Grills restaurant      Financial or Legal Service
# 5                             Zoha Restaurant           Hyderabadi Restaurant
# 6               Sri Anupama Family Restaurant               Andhra Restaurant
# 7                         Woodland Restaurant   Vegetarian / Vegan Restaurant
# 8                Nimrah Restaurant And Bakery                      Restaurant
# 9                           Azizia Restaurant                      Restaurant
# 10                          Voulga Restaurant                      Restaurant
# 11               Venue, vegetarian Restaurant               Indian Restaurant
# 12                   Dwaraka (Veg Restaurant)               Indian Restaurant
# 13  Venkey's Veg - A Multi Cuisine Restaurant            Fast Food Restaurant
# 14                        Paradise Restaurant               Indian Restaurant
# 15                         Crystal Restaurant                Asian Restaurant
# 16                          Albaik Restaurant                            None
# 17                  Dhruva Bar and Restaurant                      Restaurant
# 18                           Lucky Restaurant               Afghan Restaurant
# 19              Hanky Panky Family Restaurant            Fast Food Restaurant
# 20                      Sukh Sagar Restaurant               Indian Restaurant
# 21             Agrawala Bakers And Restaurant                     Snack Place
# 22                       Vashishta Restaurant                            None
# 23                Bademiyan Kababs Restaurant                Kebab Restaurant
# 24                    Kabul Darbar Restaurant               Afghan Restaurant
# 25                  Seena Restaurant & Bakery                          Bakery
# 26                        Carnival Restaurant            Fast Food Restaurant
# 27                          Mughal Restaurant               Indian Restaurant
# 28                   Narmada Bar & Restaurant                             Bar
# 29                      Vaishnav's Restaurant                            Food
# 30                        Nasheman Restaurant               Indian Restaurant
# 31                            Okra Restaurant                      Restaurant
# 32                          Haking Restaurant              Chinese Restaurant
# 33                     Eagle bar & restaurant                            None
# 34                         Astoria Restaurant               Indian Restaurant
# 35             Swati Multi-cuisine Restaurant   Vegetarian / Vegan Restaurant
# 36                  Green Bawarchi Restaurant               Indian Restaurant
# 37                            Swad restaurant                            None
# 38               Rangrez Fine Dine Restaurant         North Indian Restaurant
# 39        Taj Mahal -A- Restaurant And Bakery                            Café
# 40                       New Pride Restaurant                Asian Restaurant
# 41                       Kholani's Restaurant               Indian Restaurant
# 42                         Mushkab Restaurant               Indian Restaurant
# 43                     Mooch Bar & Restaurant                             Bar
# 44                     Kshetra Veg Restaurant               Indian Restaurant
# 45              New Diamond Restaurant & Cafe           Hyderabadi Restaurant
# 46             Bahar Multi Cuisine Restaurant                      Restaurant
# 47              Salwa Multicuisine Restaurant  Multicuisine Indian Restaurant
# 48                        Shanbhag Restaurant                      Restaurant
# 49                         Redrose restaurant                            Café
#
#                                               address        lat        lng  \
# 0                                                 NaN  17.395362  78.432614
# 1                                   Adj. Prince Hotel  17.394486  78.442452
# 2                                     Paradise Circle  17.441844  78.487354
# 3                                         Toli Chowli  17.396277  78.425094
# 4                                                 NaN  17.386126  78.456796
# 5                                                 NaN  17.393055  78.457642
# 6   Ahmed Commercial Complex, Ameerpet Main Road, ...  17.384757  78.455890
# 7                                                 NaN  17.402138  78.485842
# 8                                                 NaN  17.392616  78.468165
# 9                                                 NaN  17.392580  78.467255
# 10                                       Darus Salaam  17.382614  78.465828
# 11                                                NaN  17.393010  78.470391
# 12                                                NaN  17.423329  78.454327
# 13  Hotel Harsha, First Floor, Public Garden Road,...  17.394560  78.470570
# 14                                                NaN  17.403602  78.452848
# 15                                         RTC x road  17.406608  78.496268
# 16                                                NaN  17.395116  78.471534
# 17                                          Manikonda  17.400908  78.386887
# 18                                                NaN  17.404486  78.464260
# 19                           5-5-489/A&B mozamjahi rd  17.384749  78.474036
# 20                                                NaN  17.403976  78.467873
# 21                                 J. N. Road,  Abids  17.386532  78.476013
# 22                                Suchitra Crossroads  17.391191  78.475894
# 23                                                NaN  17.403130  78.460020
# 24                                       Lakdi Ka Pul  17.402985  78.461993
# 25                                                NaN  17.381676  78.474987
# 26  Door No 11-5-431, Ground Floor, Red Hills, Lak...  17.404373  78.462127
# 27                                       Lakdi-Ka-Pul  17.406657  78.464224
# 28                          Opp. Palace Heights Hotel  17.391129  78.476723
# 29                                         Kundanbagh  17.435972  78.460905
# 30                                                NaN  17.403915  78.445517
# 31                        Opposite Hussain Sagar Lake  17.423817  78.487257
# 32                                                NaN  17.405319  78.458179
# 33                                         Lakdikapul  17.404791  78.464296
# 34                                                NaN  17.406413  78.467971
# 35                                          Hyderguda  17.399397  78.479537
# 36                                                NaN  17.406462  78.461249
# 37                                                NaN  17.376700  78.475375
# 38                                        First Floor  17.428822  78.373924
# 39                                                NaN  17.390025  78.480420
# 40                                                NaN  17.394349  78.442371
# 41                                            4/1/898  17.388792  78.480760
# 42                                           Sun City  17.365207  78.397834
# 43                                                NaN  17.406388  78.451224
# 44                               Beside Eenadu Office  17.415591  78.457091
# 45                        Behind Mehdipatnam Bus Stop  17.394226  78.440545
# 46                                                NaN  17.399776  78.478477
# 47                                         Masab Tank  17.407203  78.451233
# 48                                        Basheerbagh  17.402987  78.476213
# 49         Beside indian oil petrolpump, erra manzil.  17.421255  78.455736
#
#    postalCode           state
# 0         NaN             NaN
# 1      500028       Telangana
# 2      500003       Telangana
# 3      500058       Telangana
# 4         NaN       Telangana
# 5         NaN             NaN
# 6      500073       Telangana
# 7         NaN             NaN
# 8      500004              TG
# 9         NaN             NaN
# 10        NaN       Telangana
# 11        NaN       Telangana
# 12        NaN       Telangana
# 13        NaN       Telangana
# 14        NaN       Telangana
# 15        NaN  Andhra Pradesh
# 16        NaN             NaN
# 17        NaN             NaN
# 18     500004       Telangana
# 19        NaN       Telangana
# 20        NaN             NaN
# 21     500064       Telangana
# 22        NaN       Telangana
# 23        NaN             NaN
# 24        NaN       Telangana
# 25        NaN             NaN
# 26        NaN       Telangana
# 27        NaN       Telangana
# 28        NaN       Telangana
# 29     500016       Telangana
# 30        NaN             NaN
# 31     500080       Telangana
# 32        NaN             NaN
# 33        NaN  Andhra Pradesh
# 34        NaN             NaN
# 35        NaN       Telangana
# 36        NaN             NaN
# 37        NaN       Telangana
# 38     500081       Telangana
# 39        NaN             NaN
# 40        NaN             NaN
# 41     500001       Telangana
# 42        NaN             NaN
# 43     500028       Telangana
# 44        NaN       Telangana
# 45     500028              TG
# 46        NaN  Andhra Pradesh
# 47     500004              TG
# 48        NaN       Telangana
# 49     500082       Telangana

# %%
# delete rows with none values
df_Restaurant = clean_Restaurant_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Restaurant
# Out:
#                                name                      categories  \
# 1        Akbar Fast Food Restaurant               Indian Restaurant
# 2               Paradise Restaurant           Hyderabadi Restaurant
# 3   Shah Ghouse Cafe and Restaurant               Indian Restaurant
# 6     Sri Anupama Family Restaurant               Andhra Restaurant
# 21   Agrawala Bakers And Restaurant                     Snack Place
# 29            Vaishnav's Restaurant                            Food
# 31                  Okra Restaurant                      Restaurant
# 38     Rangrez Fine Dine Restaurant         North Indian Restaurant
# 41             Kholani's Restaurant               Indian Restaurant
# 45    New Diamond Restaurant & Cafe           Hyderabadi Restaurant
# 47    Salwa Multicuisine Restaurant  Multicuisine Indian Restaurant
# 49               Redrose restaurant                            Café
#
#                                               address        lat        lng  \
# 1                                   Adj. Prince Hotel  17.394486  78.442452
# 2                                     Paradise Circle  17.441844  78.487354
# 3                                         Toli Chowli  17.396277  78.425094
# 6   Ahmed Commercial Complex, Ameerpet Main Road, ...  17.384757  78.455890
# 21                                 J. N. Road,  Abids  17.386532  78.476013
# 29                                         Kundanbagh  17.435972  78.460905
# 31                        Opposite Hussain Sagar Lake  17.423817  78.487257
# 38                                        First Floor  17.428822  78.373924
# 41                                            4/1/898  17.388792  78.480760
# 45                        Behind Mehdipatnam Bus Stop  17.394226  78.440545
# 47                                         Masab Tank  17.407203  78.451233
# 49         Beside indian oil petrolpump, erra manzil.  17.421255  78.455736
#
#    postalCode      state
# 1      500028  Telangana
# 2      500003  Telangana
# 3      500058  Telangana
# 6      500073  Telangana
# 21     500064  Telangana
# 29     500016  Telangana
# 31     500080  Telangana
# 38     500081  Telangana
# 41     500001  Telangana
# 45     500028         TG
# 47     500004         TG
# 49     500082  Telangana

# %% [markdown]
# # CAFETERIA

# %%
# search for Cafeteria
search_query = 'Cafeteria'
radius = 25000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=FN3SSHY5YSDJDHA5THZXW315E4ZJFDEO4IOTWFZZUSVKEWDZ&client_secret=VC1JLYNG2ZOZPN4E2JJ2WXD24EKJAA1VOTFYJGS3FJWKOANK&ll=17.38878595,78.4610647345315&v=20191218&query=Cafeteria&radius=25000&limit=50'

# %%
# Send the GET Request and examine the results
cresults = requests.get(url).json()
#cresults

# %%
# assign relevant part of JSON to venues
venues = cresults['response']['venues']

# tranform venues into a dataframe
Cafeteria_dataframe = json_normalize(venues)
Cafeteria_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1a1941735', 'name': 'C...    False
# 1  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
# 2  [{'id': '4bf58dd8d48988d1d3941735', 'name': 'V...    False
# 3  [{'id': '4bf58dd8d48988d128941735', 'name': 'C...    False
# 4                                                 []    False
#
#                          id      location.address location.cc location.city  \
# 0  4eabb0cfcc217eb08ede0abc  Near Library, IIIT-H          IN     Hyderabad
# 1  500e61dce4b0546f45f21742                   NaN          IN           NaN
# 2  51b042c0498ef1d0c56cdbe8                   NaN          IN           NaN
# 3  4cee29538604a1cddbc5f6c0              Madhapur          IN     Hyderabad
# 4  4e12e18baeb74afe60c9bd3d                   NaN          IN           NaN
#
#   location.country location.crossStreet  location.distance  \
# 0            India                  NaN              13503
# 1            India                  NaN               2514
# 2            India                  NaN               3295
# 3            India          Hitech city              10541
# 4            India                  NaN               2172
#
#                            location.formattedAddress  \
# 0  [Near Library, IIIT-H, Hyderabad 500032, Telan...
# 1                                            [India]
# 2                                            [India]
# 3  [Madhapur (Hitech city), Hyderabad 500081, Tel...
# 4                                            [India]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 17.44616893022691...     17.446169
# 1  [{'label': 'display', 'lat': 17.40896224975586...     17.408962
# 2  [{'label': 'display', 'lat': 17.41533119508364...     17.415331
# 3  [{'label': 'display', 'lat': 17.44376547820611...     17.443765
# 4  [{'label': 'display', 'lat': 17.40421717795755...     17.404217
#
#    location.lng location.postalCode location.state  \
# 0     78.349053              500032      Telangana
# 1     78.450424                 NaN            NaN
# 2     78.447321                 NaN            NaN
# 3     78.380259              500081      Telangana
# 4     78.448548                 NaN            NaN
#
#                                        name    referralId
# 0                                 Cafeteria  v-1576670486
# 1  Cafeteria, care hospitals, banjara hills  v-1576670486
# 2         cafeteria care out patient center  v-1576670486
# 3              IBM Cafeteria, 2A, Mindspace  v-1576670486
# 4                            Gulf cafeteria  v-1576670486

# %% [markdown]
# # CLEANING CAFETERIA DATA

# %%
# keep only columns that include venue name, and anything that is associated with location
Cafeteria_clean_columns = ['name', 'categories'] + [col for col in Cafeteria_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Cafeteria_dataframe = Cafeteria_dataframe.loc[:,Cafeteria_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list4 = row['categories']
    except:
        categories_list4 = row['venue.categories']
        
    if len(categories_list4) == 0:
        return None
    else:
        return categories_list4[0]['name']

# filter the category for each row
clean_Cafeteria_dataframe['categories'] = clean_Cafeteria_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Cafeteria_dataframe.columns = [column.split('.')[-1] for column in clean_Cafeteria_dataframe.columns]

clean_Cafeteria_dataframe.head()
# Out:
#                                        name                     categories  \
# 0                                 Cafeteria              College Cafeteria
# 1  Cafeteria, care hospitals, banjara hills              Indian Restaurant
# 2         cafeteria care out patient center  Vegetarian / Vegan Restaurant
# 3              IBM Cafeteria, 2A, Mindspace                      Cafeteria
# 4                            Gulf cafeteria                           None
#
#                 address  cc       city country  crossStreet  distance  \
# 0  Near Library, IIIT-H  IN  Hyderabad   India          NaN     13503
# 1                   NaN  IN        NaN   India          NaN      2514
# 2                   NaN  IN        NaN   India          NaN      3295
# 3              Madhapur  IN  Hyderabad   India  Hitech city     10541
# 4                   NaN  IN        NaN   India          NaN      2172
#
#                                     formattedAddress  \
# 0  [Near Library, IIIT-H, Hyderabad 500032, Telan...
# 1                                            [India]
# 2                                            [India]
# 3  [Madhapur (Hitech city), Hyderabad 500081, Tel...
# 4                                            [India]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 17.44616893022691...  17.446169  78.349053
# 1  [{'label': 'display', 'lat': 17.40896224975586...  17.408962  78.450424
# 2  [{'label': 'display', 'lat': 17.41533119508364...  17.415331  78.447321
# 3  [{'label': 'display', 'lat': 17.44376547820611...  17.443765  78.380259
# 4  [{'label': 'display', 'lat': 17.40421717795755...  17.404217  78.448548
#
#   postalCode      state                        id
# 0     500032  Telangana  4eabb0cfcc217eb08ede0abc
# 1        NaN        NaN  500e61dce4b0546f45f21742
# 2        NaN        NaN  51b042c0498ef1d0c56cdbe8
# 3     500081  Telangana  4cee29538604a1cddbc5f6c0
# 4        NaN        NaN  4e12e18baeb74afe60c9bd3d

# %%
# delete unnecessary columns
clean_Cafeteria_dataframe2= clean_Cafeteria_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Cafeteria_dataframe2
# Out:
#                                                name  \
# 0                                         Cafeteria
# 1          Cafeteria, care hospitals, banjara hills
# 2                 cafeteria care out patient center
# 3                      IBM Cafeteria, 2A, Mindspace
# 4                                    Gulf cafeteria
# 5                          Oracle Phase 3 Cafeteria
# 6                                   Akson Cafeteria
# 7                                         Cafeteria
# 8               Cafeteria - Bharat Dynamics Limited
# 9                              Cafeteria- Watermark
# 10                                    NSL Cafeteria
# 11                Cafeteria 3rd Floor Auriga A Wing
# 12                    Cafeteria at Thompson Reuters
# 13                               Al Hejaz Cafeteria
# 14                                        Cafeteria
# 15                            St. Francis Cafeteria
# 16                             PurpleTalk Cafeteria
# 17                                  Aegis Cafeteria
# 18                               St.Marys Cafeteria
# 19                              Wipro Sez Cafeteria
# 20                             10th floor Cafeteria
# 21                        Qualcomm Bldg 9 Cafeteria
# 22                                     Ou Cafeteria
# 23                               Waverock Cafeteria
# 24                                   Dell Cafeteria
# 25                   7th hell cafeteria - accenture
# 26                                     2D Cafeteria
# 27                        Ilabs 6th floor Cafeteria
# 28                             Building 8 Cafeteria
# 29                        JP Morgan Chase Cafeteria
# 30                               Deloitte Cafeteria
# 31                        Accenture hdc1A cafeteria
# 32                       Infotech Phase 2 Cafeteria
# 33                     Annapurna - Cyient Cafeteria
# 34                                     3A Cafeteria
# 35                                    ntt cafeteria
# 36                                 IBM 3A Cafeteria
# 37  Cafeteria At Mahindra Sathyam Technology Center
# 38                                Nexwave cafeteria
# 39  Cafeteria At Mahindra Sathyam Technology Center
# 40                             iLabs MLCP Cafeteria
# 41                         Oracle Phase 1 Cafeteria
# 42                             Cafeteria - CB Block
# 43                              ValueLabs Cafeteria
# 44                              Cognizant Cafeteria
# 45                           Valuelabs H2 Cafeteria
# 46                              Accenture Cafeteria
# 47                                   MSLW Cafeteria
# 48                              Cognizant Cafeteria
# 49                          3 cube towers cafeteria
#
#                        categories                             address  \
# 0               College Cafeteria                Near Library, IIIT-H
# 1               Indian Restaurant                                 NaN
# 2   Vegetarian / Vegan Restaurant                                 NaN
# 3                       Cafeteria                            Madhapur
# 4                            None                                 NaN
# 5                       Cafeteria                           Hyderabad
# 6               Indian Restaurant                          Panjagutta
# 7               College Cafeteria       Near Basketball Court, IIIT-H
# 8                       Cafeteria                         Kanchanbagh
# 9                  Sandwich Place                                 NaN
# 10                          Diner                                 NaN
# 11                           Café                                 NaN
# 12                      Cafeteria                                 NaN
# 13             Falafel Restaurant                                 NaN
# 14           Fast Food Restaurant              Mahindra Satyam campus
# 15              College Cafeteria       St. Francis College for Women
# 16              Indian Restaurant                                 NaN
# 17              Indian Restaurant                                 NaN
# 18              College Cafeteria                 8-3-229,Taher Villa
# 19                     Food Court                                 NaN
# 20                      Cafeteria                              I Labs
# 21                      Cafeteria                                 NaN
# 22                     Restaurant                                 NaN
# 23                     Food Court                          Gachibowli
# 24                      Cafeteria                                Dell
# 25                     Restaurant                           Raidurgam
# 26                    Event Space                               Ilabs
# 27                      Cafeteria                               ILabs
# 28              Indian Restaurant                    Raheja Mindspace
# 29                      Cafeteria                                 NaN
# 30                     Food Court             deloitte street,d block
# 31                          Diner                                 NaN
# 32                      Cafeteria                                 NaN
# 33                      Cafeteria                                 NaN
# 34                           Food                      IBM, Mindspace
# 35                      Cafeteria                          Cyber Perl
# 36                     Food Court                 Mindspace, Madhapur
# 37                           Café                                 NaN
# 38                     Food Court                                 NaN
# 39                      Cafeteria  Mahindra Sathyam Technology Center
# 40              College Cafeteria                                 NaN
# 41                      Cafeteria                Oracle India Pvt Ltd
# 42                      Cafeteria                      Computer Block
# 43                         Office                                 NaN
# 44              Indian Restaurant    phase-2,3rd floor,Dlf Cyber city
# 45                      Cafeteria                                 NaN
# 46                      Cafeteria                                 NaN
# 47              Indian Restaurant                                 NaN
# 48              Indian Restaurant                             G Floor
# 49                           Café                                 NaN
#
#           lat        lng postalCode          state
# 0   17.446169  78.349053     500032      Telangana
# 1   17.408962  78.450424        NaN            NaN
# 2   17.415331  78.447321        NaN            NaN
# 3   17.443765  78.380259     500081      Telangana
# 4   17.404217  78.448548        NaN            NaN
# 5   17.449396  78.373959        NaN      Telangana
# 6   17.424736  78.453783        NaN      Telangana
# 7   17.447850  78.347720     500032      Telangana
# 8   17.330794  78.507896        NaN      Telangana
# 9   17.454240  78.370970        NaN            NaN
# 10  17.412256  78.435894        NaN            NaN
# 11  17.435594  78.382481        NaN            NaN
# 12  17.437217  78.381548        NaN            NaN
# 13  17.391796  78.426712        NaN            NaN
# 14  17.542933  78.430105        NaN      Telangana
# 15  17.437108  78.460816    5000016      Telangana
# 16  17.426099  78.421579        NaN            NaN
# 17  17.441179  78.458773        NaN            NaN
# 18  17.436728  78.428378        NaN      Telangana
# 19  17.426861  78.343516        NaN            NaN
# 20  17.432606  78.386908        NaN      Telangana
# 21  17.441126  78.380920        NaN            NaN
# 22  17.423067  78.530954        NaN            NaN
# 23  17.418998  78.348175        NaN            NaN
# 24  17.448481  78.373709        NaN      Telangana
# 25  17.420660  78.374804        NaN  Andhrapradesh
# 26  17.432840  78.386331        NaN      Telangana
# 27  17.432546  78.387731        NaN      Telangana
# 28  17.440500  78.380271        NaN      Telangana
# 29  17.438493  78.381976        NaN            NaN
# 30  17.447867  78.376084        NaN      Telangana
# 31  17.442213  78.380954        NaN            NaN
# 32  17.438345  78.382095        NaN            NaN
# 33  17.437772  78.380075        NaN            NaN
# 34  17.444284  78.379978     500081      Telangana
# 35  17.446034  78.376482        NaN            NaN
# 36  17.443661  78.379630        NaN      Telangana
# 37  17.570479  78.434516        NaN            NaN
# 38  17.442330  78.377310        NaN            NaN
# 39  17.571861  78.431942        NaN      Telangana
# 40  17.432834  78.388023        NaN            NaN
# 41  17.449474  78.374065     500081      Telangana
# 42  17.573440  78.436944        NaN      Telangana
# 43  17.449493  78.372832        NaN            NaN
# 44  17.446835  78.360453        NaN      Telangana
# 45  17.446835  78.371647     500081             TG
# 46  17.424582  78.349811        NaN            NaN
# 47  17.452509  78.370304        NaN            NaN
# 48  17.446453  78.352042        NaN            NaN
# 49  17.454760  78.370182        NaN            NaN

# %%
# delete rows with none values
df_Cafeteria = clean_Cafeteria_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Cafeteria
# Out:
#                             name         categories  \
# 0                      Cafeteria  College Cafeteria
# 3   IBM Cafeteria, 2A, Mindspace          Cafeteria
# 7                      Cafeteria  College Cafeteria
# 15         St. Francis Cafeteria  College Cafeteria
# 34                  3A Cafeteria               Food
# 41      Oracle Phase 1 Cafeteria          Cafeteria
#
#                           address        lat        lng postalCode      state
# 0            Near Library, IIIT-H  17.446169  78.349053     500032  Telangana
# 3                        Madhapur  17.443765  78.380259     500081  Telangana
# 7   Near Basketball Court, IIIT-H  17.447850  78.347720     500032  Telangana
# 15  St. Francis College for Women  17.437108  78.460816    5000016  Telangana
# 34                 IBM, Mindspace  17.444284  78.379978     500081  Telangana
# 41           Oracle India Pvt Ltd  17.449474  78.374065     500081  Telangana

# %% [markdown]
# # SHOPPING

# %%
# search for Shopping
search_query = 'Shopping'
radius = 25000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=FN3SSHY5YSDJDHA5THZXW315E4ZJFDEO4IOTWFZZUSVKEWDZ&client_secret=VC1JLYNG2ZOZPN4E2JJ2WXD24EKJAA1VOTFYJGS3FJWKOANK&ll=17.38878595,78.4610647345315&v=20191218&query=Shopping&radius=25000&limit=50'

# %%
# Send the GET Request and examine the results
sresults = requests.get(url).json()
#sresults

# %%
# assign relevant part of JSON to venues
venues = sresults['response']['venues']

# tranform venues into a dataframe
Shopping_dataframe = json_normalize(venues)
Shopping_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d103951735', 'name': 'C...    False
# 1  [{'id': '5744ccdfe4b0c0459246b4dc', 'name': 'S...    False
# 2  [{'id': '4bf58dd8d48988d103951735', 'name': 'C...    False
# 3  [{'id': '4bf58dd8d48988d103951735', 'name': 'C...    False
# 4  [{'id': '4bf58dd8d48988d103951735', 'name': 'C...    False
#
#                          id location.address location.cc location.city  \
# 0  5156fa20e4b00f5f95a76ff7              NaN          IN           NaN
# 1  584d3f1e8ae363062bdceed0              NaN          IN           NaN
# 2  517252afe4b0e656c21a8b25              NaN          IN           NaN
# 3  4f8fd59ce4b040e3a7cbfd9a     Mehadipatnam          IN     Hyderabad
# 4  517254fae4b02cd2b90e54c2              NaN          IN           NaN
#
#   location.country location.crossStreet  location.distance  \
# 0            India                  NaN               2844
# 1            India                  NaN               8396
# 2            India                  NaN               2602
# 3            India                  NaN               2582
# 4            India                  NaN               2676
#
#                      location.formattedAddress  \
# 0                                      [India]
# 1                                      [India]
# 2                                      [India]
# 3  [Mehadipatnam, Hyderabad, Telangana, India]
# 4                                      [India]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 17.38850544801230...     17.388505
# 1  [{'label': 'display', 'lat': 17.367939, 'lng':...     17.367939
# 2  [{'label': 'display', 'lat': 17.39515314863346...     17.395153
# 3  [{'label': 'display', 'lat': 17.39513275599642...     17.395133
# 4  [{'label': 'display', 'lat': 17.39492065932736...     17.394921
#
#    location.lng location.postalCode location.state  \
# 0     78.487839                 NaN            NaN
# 1     78.537025                 NaN            NaN
# 2     78.437489                 NaN            NaN
# 3     78.437678                 NaN      Telangana
# 4     78.436706                 NaN            NaN
#
#                                                 name    referralId  \
# 0                                 koti shopping road  v-1576670667
# 1                                           Shopping  v-1576670667
# 2                             Chennail Shopping Mall  v-1576670667
# 3                                  CMR Shopping Mall  v-1576670667
# 4  Chennai Shopping Mall, P.V.Naras I mha Rao Exp...  v-1576670667
#
#   venuePage.id
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %% [markdown]
# # CLEAN SHOP DATA

# %%
# keep only columns that include venue name, and anything that is associated with location
Shopping_clean_columns = ['name', 'categories'] + [col for col in Shopping_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Shopping_dataframe = Shopping_dataframe.loc[:,Shopping_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

# filter the category for each row
clean_Shopping_dataframe['categories'] = clean_Shopping_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Shopping_dataframe.columns = [column.split('.')[-1] for column in clean_Shopping_dataframe.columns]

clean_Shopping_dataframe.head()
# Out:
#                                                 name      categories  \
# 0                                 koti shopping road  Clothing Store
# 1                                           Shopping  Shopping Plaza
# 2                             Chennail Shopping Mall  Clothing Store
# 3                                  CMR Shopping Mall  Clothing Store
# 4  Chennai Shopping Mall, P.V.Naras I mha Rao Exp...  Clothing Store
#
#         address  cc       city country crossStreet  distance  \
# 0           NaN  IN        NaN   India         NaN      2844
# 1           NaN  IN        NaN   India         NaN      8396
# 2           NaN  IN        NaN   India         NaN      2602
# 3  Mehadipatnam  IN  Hyderabad   India         NaN      2582
# 4           NaN  IN        NaN   India         NaN      2676
#
#                               formattedAddress  \
# 0                                      [India]
# 1                                      [India]
# 2                                      [India]
# 3  [Mehadipatnam, Hyderabad, Telangana, India]
# 4                                      [India]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 17.38850544801230...  17.388505  78.487839
# 1  [{'label': 'display', 'lat': 17.367939, 'lng':...  17.367939  78.537025
# 2  [{'label': 'display', 'lat': 17.39515314863346...  17.395153  78.437489
# 3  [{'label': 'display', 'lat': 17.39513275599642...  17.395133  78.437678
# 4  [{'label': 'display', 'lat': 17.39492065932736...  17.394921  78.436706
#
#   postalCode      state                        id
# 0        NaN        NaN  5156fa20e4b00f5f95a76ff7
# 1        NaN        NaN  584d3f1e8ae363062bdceed0
# 2        NaN        NaN  517252afe4b0e656c21a8b25
# 3        NaN  Telangana  4f8fd59ce4b040e3a7cbfd9a
# 4        NaN        NaN  517254fae4b02cd2b90e54c2

# %%
# delete unnecessary columns
clean_Shopping_dataframe2= clean_Shopping_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Shopping_dataframe2
# Out:
#                                                  name          categories  \
# 0                                  koti shopping road      Clothing Store
# 1                                            Shopping      Shopping Plaza
# 2                              Chennail Shopping Mall      Clothing Store
# 3                                   CMR Shopping Mall      Clothing Store
# 4   Chennai Shopping Mall, P.V.Naras I mha Rao Exp...      Clothing Store
# 5                           Kalaniketan Shopping Mall      Clothing Store
# 6                                     shopping centre           Gift Shop
# 7                           Innovation Shopping Point           Gift Shop
# 8                           South India Shopping Mall       Women's Store
# 9                           South India Shopping Mall      Shopping Plaza
# 10                          South India Shopping Mall       Shopping Mall
# 11                                   Sm Shopping Mall       Shopping Mall
# 12                           Padmavathi Shopping Mall                None
# 13                              Chennai Shopping Mall                None
# 14                              Chennai Shopping Mall      Clothing Store
# 15                           Thailand Shopping Center           Gift Shop
# 16                                    shoppingmantraz         IT Services
# 17                                   City Center Mall       Shopping Mall
# 18                              Chennai Shopping Mall      Clothing Store
# 19                                  CMR Shopping Mall       Shopping Mall
# 20                          kalaniketan Shopping Mall      Clothing Store
# 21                          South india shopping mall       Shopping Mall
# 22                           vasundhara shopping mall       Shopping Mall
# 23                           ShoppingMantraz Cashback    Business Service
# 24                          South India Shopping Mall       Shopping Mall
# 25                              Chennai Shopping Mall            Boutique
# 26                              Rainbow Shopping Mall       Shopping Mall
# 27                          South India Shopping Mall       Shopping Mall
# 28                         kalanikethan Shopping Mall       Women's Store
# 29                                 Auchan Hypermarket    Department Store
# 30                              Chennai Shopping Mall         Fabric Shop
# 31                                      Shopping Mart   Convenience Store
# 32                             Telkar's Shopping Mall      Clothing Store
# 33                               Serena Shopping Mall       Shopping Mall
# 34                      Geetha krishna shopping point      Clothing Store
# 35                       Gita Krishna Shopping Center      Clothing Store
# 36                                  Klm Shopping Mall        Costume Shop
# 37                              Chennai shopping mall      Clothing Store
# 38                               KPHB Street Shopping              Market
# 39                          Kalaniketan Shopping Mall                None
# 40                                    6 Shopping Mall       Shopping Mall
# 41                          Vayupuri Shopping Complex  Salon / Barbershop
# 42                              Chennai Shopping Mall       Shopping Mall
# 43                        colors family shopping mall       Shopping Mall
# 44               Maangalya Shopping Mall in Hyderabad       Shopping Mall
# 45                              Chennai Shopping Mall      Clothing Store
# 46                                Kuber Shopping Mall      Clothing Store
# 47                                                Max      Clothing Store
#
#                                            address        lat        lng  \
# 0                                              NaN  17.388505  78.487839
# 1                                              NaN  17.367939  78.537025
# 2                                              NaN  17.395153  78.437489
# 3                                     Mehadipatnam  17.395133  78.437678
# 4                                              NaN  17.394921  78.436706
# 5                                              NaN  17.405158  78.480126
# 6                                         r.p road  17.432668  78.493590
# 7                                              NaN  17.392132  78.434639
# 8                                              NaN  17.435398  78.444784
# 9                                          attapur  17.361526  78.427290
# 10                                           Patny  17.441913  78.495741
# 11                                             NaN  17.412104  78.423075
# 12                                    opp. Chermas  17.431741  78.447849
# 13                                     Chandanagar  17.430734  78.446520
# 14                                             NaN  17.434242  78.446594
# 15                                             NaN  17.401384  78.412430
# 16                                       S R Nagar  17.441553  78.448485
# 17                                   Banjara Hills  17.415156  78.448943
# 18                                             NaN  17.439280  78.494681
# 19  Sarojini Devi Rd, Telangana Region, Kalasiguda  17.441746  78.493605
# 20                                   Chaitanyapuri  17.368452  78.530410
# 21                                      Gachibowli  17.435361  78.368717
# 22                                             NaN  17.397528  78.532837
# 23                            S.R.Nagar, Hyderabad  17.395733  78.539393
# 24                                             NaN  17.492826  78.404435
# 25                                        Kothapet  17.362967  78.543781
# 26                                        Karkhana  17.464139  78.502934
# 27                                        Kothapet  17.358498  78.544859
# 28                                             NaN  17.362756  78.543451
# 29                          6-3-1112, Oasis Centre  17.430479  78.456133
# 30                                             NaN  17.505049  78.478134
# 31               Mahindra Satyam Technology Center  17.569427  78.433425
# 32                                    Chanda Nagar  17.482865  78.406770
# 33                                             NaN  17.511353  78.447319
# 34                                             NaN  17.336058  78.568569
# 35                                             NaN  17.334999  78.567921
# 36                                             NaN  17.503017  78.479830
# 37                                             NaN  17.494742  78.399300
# 38                                             NaN  17.494947  78.398758
# 39                                      Kukatpally  17.495399  78.398701
# 40                                             NaN  17.495624  78.396929
# 41                           Road No 3, Sainikpuri  17.483989  78.544881
# 42                                             NaN  17.480928  78.555458
# 43                                             NaN  17.544433  78.491835
# 44          Sri Durga Colony, Miyapur Madeenaguda   17.497717  78.339901
# 45                                             NaN  17.495302  78.333130
# 46                                             NaN  17.495365  78.312447
# 47                                   A S Rao Nagar  17.478846  78.558801
#
#    postalCode           state
# 0         NaN             NaN
# 1         NaN             NaN
# 2         NaN             NaN
# 3         NaN       Telangana
# 4         NaN             NaN
# 5         NaN             NaN
# 6         NaN  Andhra Pradesh
# 7         NaN             NaN
# 8         NaN       Telangana
# 9      500030       Telangana
# 10        NaN             NaN
# 11        NaN             NaN
# 12        NaN       Telangana
# 13        NaN             NaN
# 14        NaN             NaN
# 15        NaN             NaN
# 16        NaN       Telangana
# 17     500034       Telangana
# 18        NaN             NaN
# 19        NaN  Andhra Pradesh
# 20        NaN       Telangana
# 21        NaN       Telangana
# 22        NaN             NaN
# 23     500016       Telangana
# 24        NaN       Telangana
# 25        NaN             NaN
# 26     500009       Telangana
# 27        NaN       Telangana
# 28        NaN             NaN
# 29        NaN       Telangana
# 30     500067       Telangana
# 31        NaN       Telangana
# 32        NaN             NaN
# 33        NaN             NaN
# 34        NaN             NaN
# 35        NaN             NaN
# 36        NaN       Telangana
# 37        NaN             NaN
# 38        NaN             NaN
# 39     500072       Telangana
# 40        NaN             NaN
# 41        NaN       Telangana
# 42        NaN             NaN
# 43        NaN             NaN
# 44     500050       Telangana
# 45        NaN             NaN
# 46        NaN             NaN
# 47        NaN             NaN

# %%
# delete rows which its category is not Shopping Mall
df_Shopping = clean_Shopping_dataframe2[clean_Shopping_dataframe2.categories == 'Shopping Mall']
df_Shopping
# Out:
#                                     name     categories  \
# 10             South India Shopping Mall  Shopping Mall
# 11                      Sm Shopping Mall  Shopping Mall
# 17                      City Center Mall  Shopping Mall
# 19                     CMR Shopping Mall  Shopping Mall
# 21             South india shopping mall  Shopping Mall
# 22              vasundhara shopping mall  Shopping Mall
# 24             South India Shopping Mall  Shopping Mall
# 26                 Rainbow Shopping Mall  Shopping Mall
# 27             South India Shopping Mall  Shopping Mall
# 33                  Serena Shopping Mall  Shopping Mall
# 40                       6 Shopping Mall  Shopping Mall
# 42                 Chennai Shopping Mall  Shopping Mall
# 43           colors family shopping mall  Shopping Mall
# 44  Maangalya Shopping Mall in Hyderabad  Shopping Mall
#
#                                            address        lat        lng  \
# 10                                           Patny  17.441913  78.495741
# 11                                             NaN  17.412104  78.423075
# 17                                   Banjara Hills  17.415156  78.448943
# 19  Sarojini Devi Rd, Telangana Region, Kalasiguda  17.441746  78.493605
# 21                                      Gachibowli  17.435361  78.368717
# 22                                             NaN  17.397528  78.532837
# 24                                             NaN  17.492826  78.404435
# 26                                        Karkhana  17.464139  78.502934
# 27                                        Kothapet  17.358498  78.544859
# 33                                             NaN  17.511353  78.447319
# 40                                             NaN  17.495624  78.396929
# 42                                             NaN  17.480928  78.555458
# 43                                             NaN  17.544433  78.491835
# 44          Sri Durga Colony, Miyapur Madeenaguda   17.497717  78.339901
#
#    postalCode           state
# 10        NaN             NaN
# 11        NaN             NaN
# 17     500034       Telangana
# 19        NaN  Andhra Pradesh
# 21        NaN       Telangana
# 22        NaN             NaN
# 24        NaN       Telangana
# 26     500009       Telangana
# 27        NaN       Telangana
# 33        NaN             NaN
# 40        NaN             NaN
# 42        NaN             NaN
# 43        NaN             NaN
# 44     500050       Telangana

# %% [markdown]
# # GENERATING MAP FOR VISUALIZING HOTELS,CAFETERIA AND SHOPPING STORES

# %%
# create dataframe of hotels, shopping stores and Cafeteria
hotel_neighbourhood_df = pd.concat([df_hotel, df_Cafeteria, df_Shopping], ignore_index=True)
hotel_neighbourhood_df
# Out:
#                                     name         categories  \
# 0                   Hotel Celestee Grand              Hotel
# 1                           Hotel Harsha              Hotel
# 2                              Cafeteria  College Cafeteria
# 3           IBM Cafeteria, 2A, Mindspace          Cafeteria
# 4                              Cafeteria  College Cafeteria
# 5                  St. Francis Cafeteria  College Cafeteria
# 6                           3A Cafeteria               Food
# 7               Oracle Phase 1 Cafeteria          Cafeteria
# 8              South India Shopping Mall      Shopping Mall
# 9                       Sm Shopping Mall      Shopping Mall
# 10                      City Center Mall      Shopping Mall
# 11                     CMR Shopping Mall      Shopping Mall
# 12             South india shopping mall      Shopping Mall
# 13              vasundhara shopping mall      Shopping Mall
# 14             South India Shopping Mall      Shopping Mall
# 15                 Rainbow Shopping Mall      Shopping Mall
# 16             South India Shopping Mall      Shopping Mall
# 17                  Serena Shopping Mall      Shopping Mall
# 18                       6 Shopping Mall      Shopping Mall
# 19                 Chennai Shopping Mall      Shopping Mall
# 20           colors family shopping mall      Shopping Mall
# 21  Maangalya Shopping Mall in Hyderabad      Shopping Mall
#
#                                            address        lat        lng  \
# 0      H.no - 11-6-460-465, Dargah Road, Nampally,  17.392014  78.465233
# 1                            39 public garden road  17.392818  78.470785
# 2                             Near Library, IIIT-H  17.446169  78.349053
# 3                                         Madhapur  17.443765  78.380259
# 4                    Near Basketball Court, IIIT-H  17.447850  78.347720
# 5                    St. Francis College for Women  17.437108  78.460816
# 6                                   IBM, Mindspace  17.444284  78.379978
# 7                             Oracle India Pvt Ltd  17.449474  78.374065
# 8                                            Patny  17.441913  78.495741
# 9                                              NaN  17.412104  78.423075
# 10                                   Banjara Hills  17.415156  78.448943
# 11  Sarojini Devi Rd, Telangana Region, Kalasiguda  17.441746  78.493605
# 12                                      Gachibowli  17.435361  78.368717
# 13                                             NaN  17.397528  78.532837
# 14                                             NaN  17.492826  78.404435
# 15                                        Karkhana  17.464139  78.502934
# 16                                        Kothapet  17.358498  78.544859
# 17                                             NaN  17.511353  78.447319
# 18                                             NaN  17.495624  78.396929
# 19                                             NaN  17.480928  78.555458
# 20                                             NaN  17.544433  78.491835
# 21          Sri Durga Colony, Miyapur Madeenaguda   17.497717  78.339901
#
#    postalCode           state
# 0      500001       Telangana
# 1      500001       Telangana
# 2      500032       Telangana
# 3      500081       Telangana
# 4      500032       Telangana
# 5     5000016       Telangana
# 6      500081       Telangana
# 7      500081       Telangana
# 8         NaN             NaN
# 9         NaN             NaN
# 10     500034       Telangana
# 11        NaN  Andhra Pradesh
# 12        NaN       Telangana
# 13        NaN             NaN
# 14        NaN       Telangana
# 15     500009       Telangana
# 16        NaN       Telangana
# 17        NaN             NaN
# 18        NaN             NaN
# 19        NaN             NaN
# 20        NaN             NaN
# 21     500050       Telangana

# %%
# Generate map to visualize hotel neighbourhood including shopping stores and Cafeteria 
hotel_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(hotel_neighbourhood_df['lat'], hotel_neighbourhood_df['lng'], 
                                           hotel_neighbourhood_df['name'], hotel_neighbourhood_df['categories'],\
                                               hotel_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(hotel_map)  
    
hotel_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # MAP TO VISUALIZE PARK, RESTAURANT AND CAFETERIA AND HOW THEY CLUSTER TOGETHER

# %%
# create dataframe of Park, Restaurant and Cafeteria
park_neighbourhood_df = pd.concat([df_park, df_Restaurant, df_Cafeteria,], ignore_index=True)
park_neighbourhood_df
# Out:
#                                name                      categories  \
# 0                 Chacha Nehru Park                            Park
# 1       Ashok Nagar Children's Park                            Park
# 2        Akbar Fast Food Restaurant               Indian Restaurant
# 3               Paradise Restaurant           Hyderabadi Restaurant
# 4   Shah Ghouse Cafe and Restaurant               Indian Restaurant
# 5     Sri Anupama Family Restaurant               Andhra Restaurant
# 6    Agrawala Bakers And Restaurant                     Snack Place
# 7             Vaishnav's Restaurant                            Food
# 8                   Okra Restaurant                      Restaurant
# 9      Rangrez Fine Dine Restaurant         North Indian Restaurant
# 10             Kholani's Restaurant               Indian Restaurant
# 11    New Diamond Restaurant & Cafe           Hyderabadi Restaurant
# 12    Salwa Multicuisine Restaurant  Multicuisine Indian Restaurant
# 13               Redrose restaurant                            Café
# 14                        Cafeteria               College Cafeteria
# 15     IBM Cafeteria, 2A, Mindspace                       Cafeteria
# 16                        Cafeteria               College Cafeteria
# 17            St. Francis Cafeteria               College Cafeteria
# 18                     3A Cafeteria                            Food
# 19         Oracle Phase 1 Cafeteria                       Cafeteria
#
#                                               address        lat        lng  \
# 0                                          Masab Tank  17.401969  78.449486
# 1                               Ashok Nagar Main Road  17.405775  78.489748
# 2                                   Adj. Prince Hotel  17.394486  78.442452
# 3                                     Paradise Circle  17.441844  78.487354
# 4                                         Toli Chowli  17.396277  78.425094
# 5   Ahmed Commercial Complex, Ameerpet Main Road, ...  17.384757  78.455890
# 6                                  J. N. Road,  Abids  17.386532  78.476013
# 7                                          Kundanbagh  17.435972  78.460905
# 8                         Opposite Hussain Sagar Lake  17.423817  78.487257
# 9                                         First Floor  17.428822  78.373924
# 10                                            4/1/898  17.388792  78.480760
# 11                        Behind Mehdipatnam Bus Stop  17.394226  78.440545
# 12                                         Masab Tank  17.407203  78.451233
# 13         Beside indian oil petrolpump, erra manzil.  17.421255  78.455736
# 14                               Near Library, IIIT-H  17.446169  78.349053
# 15                                           Madhapur  17.443765  78.380259
# 16                      Near Basketball Court, IIIT-H  17.447850  78.347720
# 17                      St. Francis College for Women  17.437108  78.460816
# 18                                     IBM, Mindspace  17.444284  78.379978
# 19                               Oracle India Pvt Ltd  17.449474  78.374065
#
#    postalCode      state
# 0      500028  Telangana
# 1      500020  Telangana
# 2      500028  Telangana
# 3      500003  Telangana
# 4      500058  Telangana
# 5      500073  Telangana
# 6      500064  Telangana
# 7      500016  Telangana
# 8      500080  Telangana
# 9      500081  Telangana
# 10     500001  Telangana
# 11     500028         TG
# 12     500004         TG
# 13     500082  Telangana
# 14     500032  Telangana
# 15     500081  Telangana
# 16     500032  Telangana
# 17    5000016  Telangana
# 18     500081  Telangana
# 19     500081  Telangana

# %%
# Generate map to visualize park neighbourhood including Restaurant and Cafeteria 
park_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(park_neighbourhood_df['lat'], park_neighbourhood_df['lng'], 
                                           park_neighbourhood_df['name'], park_neighbourhood_df['categories'],\
                                               park_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(park_map)  
    
park_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
